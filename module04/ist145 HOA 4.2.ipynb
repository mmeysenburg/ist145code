# %% [markdown]
# #HOA 4.2
#
# To practice with dictionaries, write the function requested below.
#
# ---

# %% [markdown]
# ##1. Write a `letterFrequency()` function
#
# This function is a bit of a flashback to Module 3, when we were looking a ciphers. One common task we will perform when trying to break a cipher is to do a letter frequency analysis. Write a function called `letterFrequency()` that takes a string with some text, and returns a dictionary with the 26 lowercase English letters as keys, and the number of times each letter occurs in the text as values.

# %% [markdown]
# ###1.1 Iterate through a string
#
# Since we're flashing back, let's review how to iterate through the characters in a string. Refer to Section 3.4.1 if you need a reminder, then write a for loop to iterate through, and print, all the alphabetic characters in the string named `pangram` defined in the following cell. Your output should look like this:
#
# ```
# t
# h
# e
# f
# i
# v
# e
# b
# o
# x
# i
# n
# g
# w
# i
# z
# a
# r
# d
# s
# j
# u
# m
# p
# q
# u
# i
# c
# k
# l
# y
# ```
#
# Things to think about:
#
# 1. Note the output is all lowercase, but the original string has an uppercase letter. How can you convert from lowercase to uppercase?
# 2. Note the output does *not* contain the spaces or period from the original string. How can you only print the letters?

# %%
pangram = 'The five boxing wizards jump quickly.'

# %%
# TODO: write a for loop to print all the alphabetic characters in pangram

# %% [markdown]
# ###1.2 Starting the dictionary
#
# Review the basic usage of how to add a new key, value pair to a dictionary in Section 4.5.3 of your text. Then, write a `for` loop in the code cell below that adds each character from `pangram` as a key in a dictionary named `counts`, with the value 0.

# %%
# TODO: use a for loop similar to the one in part 1.1 to add keys to a dictionary
# first, make an empty dictionary named counts

# write your for loop here

# %%
# execute this cell to verify that your loop worked as it should
testData = {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 0, 'f': 0, 'g': 0, 'h': 0, 
            'i': 0, 'j': 0, 'k': 0, 'l': 0, 'm': 0, 'n': 0, 'o': 0, 'p': 0, 
            'q': 0, 'r': 0, 's': 0, 't': 0, 'u': 0, 'v': 0, 'w': 0, 'x': 0, 
            'y': 0, 'z': 0}

if counts == testData:
  print('Awesome!')
else:
  print('Something is wrong.')

# %% [markdown]
# ###1.3 Now write the function
#
# Now you have almost everything you need to write the `letterFrequency()` function. Before writing the function, review how the item count is incremented in the `mode()` function from Section 4.5.3 of your text.
#
# Finish the function below.

# %%
# TODO: finish the letterFrequency() function
def letterFrequency(myString):
  """
  Count the letter frequency in a string.

  parameters
  ----------
  myString : string containing the text to examine

  returns
  -------
    A dictionary of letter:count pairs, containing the letter frequency.
  """

# %% [markdown]
# ###1.4 Test your `letterFrequency()` function
#
# Once you have written your `letterFrequency()` function, test it by executing the code cell below. If your function fails any of the test cases, re-examine the requirements and your code to see if you can fix it.

# %%
testData = [('', {'a': 0, 'b': 0, 'c': 0, 'd': 0, 'e': 0, 'f': 0, 'g': 0,
                  'h': 0, 'i': 0, 'j': 0, 'k': 0, 'l': 0, 'm': 0, 'n': 0,
                  'o': 0, 'p': 0, 'q': 0, 'r': 0, 's': 0, 't': 0, 'u': 0,
                  'v': 0, 'w': 0, 'x': 0, 'y': 0, 'z': 0}),
            ('aaaaabbbbbcccccdddddeeeeefffffggggghhhhhiiiiijjjjjkkkkklllllmmmmmnnnnnooooopppppqqqqqrrrrrssssstttttuuuuuvvvvvwwwwwxxxxxyyyyyzzzzz',
             {'a': 5, 'b': 5, 'c': 5, 'd': 5, 'e': 5, 'f': 5, 'g': 5, 'h': 5,
              'i': 5, 'j': 5, 'k': 5, 'l': 5, 'm': 5, 'n': 5, 'o': 5, 'p': 5,
              'q': 5, 'r': 5, 's': 5, 't': 5, 'u': 5, 'v': 5, 'w': 5, 'x': 5,
              'y': 5, 'z': 5}),
            ('We promptly judged antique ivory buckles for the next prize.', 
             {'a': 1, 'b': 1, 'c': 1, 'd': 2, 'e': 7, 'f': 1, 'g': 1, 'h': 1,
              'i': 3, 'j': 1, 'k': 1, 'l': 2, 'm': 1, 'n': 2, 'o': 3, 'p': 3,
              'q': 1, 'r': 4, 's': 1, 't': 4, 'u': 3, 'v': 1, 'w': 1, 'x': 1,
              'y': 2, 'z': 1})]

numCorrect = 0
for i, (text, dict) in enumerate(testData):
  print('Test case %d:' % (i + 1))
  print('\tText: %s' % text)
  resDict = letterFrequency(text)
  if dict == resDict:
    numCorrect += 1
    print('\tPASSED!')
  else:
    print('\tFAILED!')

if numCorrect == len(testData):
  print('Awesome!')
