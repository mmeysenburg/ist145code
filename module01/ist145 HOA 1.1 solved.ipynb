# %% [markdown]
# #HOA 1.1
#
# These hands-on activities are based on sections 1.1 - 1.5.1 of your text.
#
# ---

# %% [markdown]
# ##1 Expressions with integers
#
# In the code cells below, create expressions involving integer numbers to solve each of the indicated problems.

# %% [markdown]
# ###1.1 Simple sums
#
# In the first cell below, create and execute an expression to find the sum of the numbers 8, 9, and 10.
#
# In the second cell below, create an exectue an expression to find the product of the numbers 8, 9, and 10.

# %%
# Cell 1: sum of 8, 9, 10
8 + 9 + 10
# Out:
# 27

# %%
# Cell 2: product of 8, 9, 10
8 * 9 * 10
# Out:
# 720

# %% [markdown]
# ###1.2 A little algebra
#
# In the first cell below, create and execute an expression to find the number of seconds in a non-leap year.
#
# In the second cell below, create and execute an expression to find the number of inches in one mile. Hint: There are 5,280 feet in a mile.

# %%
# Cell 1: number of seconds in a non-leap year
365 * 24 * 60 * 60
# Out:
# 31536000

# %%
# Cell 2: number of inches in a mile
5280 * 12
# Out:
# 63360

# %% [markdown]
# ###1.3 A little geometry
#
# In the first cell below, create and execute an expression to calculate how much land is covered by the Great Pyramid in Egypt. Each side of the pyramid's base is 230 meters in length.
#
# In the second cell below, create and execute an expression to calculate the number of 2-ft<sup>2</sup> tiles needed to cover the floor of a 10 by 12 foot room.

# %%
# Cell 1: area of the base of the Great Pyramid
230 * 230
# Out:
# 52900

# %%
# Cell 2: number of tiles required to cover a 10x12 room
(10 * 12) / 2
# Out:
# 60.0

# %% [markdown]
# ---
#
# ##2 Floating-point numbers
#
# In the code cells below, create expressions involving floating-point numbers to solve each of the specified problems.

# %% [markdown]
# ###2.1 About average
#
# In the first cell below, create and execute an expression to find the average age of five people. You may use the ages of real people you know, or use ages of your own choosing. *Get this average using integer division.*
#
# In the second cell below, repeat the same average age calculation, but *get this average using floating-point division.*

# %%
# Cell 1: average age of five people, using integer division
(68 + 54 + 58 + 26 + 27) // 5
# Out:
# 46

# %%
# Cell 2: average age of five people, using floating-point division
(68 + 54 + 58 + 26 + 27) / 5
# Out:
# 46.6

# %% [markdown]
# ###2.2 A little more geometry
#
# In the cell below, find the volume of a sphere with a radius 2.5, using this formula:
#
# ![CodeCogsEqn.gif](data:image/gif;base64,...)
#
# You may approximate the value of π as 3.14159.

# %%
# Cell 1: volume of a sphere with radius of 2.5
(4 / 3) * 3.14159 * 2.5**3
# Out:
# 65.44979166666666

# %% [markdown]
# ---
#
# ##3 Celsius to Fahrenheit
#
# It is easy to use Python to access weather forecasts and conditions from the [National Weather Service](https://www.weather.gov/) -- in fact, you will do that in Module 5!
#
# One issue is that the current temperature is reported in degrees Celsius, rather than degrees Fahrenheit. Suppose that the current temperature is 5.6 degrees Celsius, what is the temperature in Fahrenheit? Look up the conversion formula and write an expression in the cell below to determine the temperature in degrees Fahrenheit.

# %%
# Cell 1: degrees F for 5.6 degrees C
(9 / 5) * 5.6 + 32
# Out:
# 42.08
