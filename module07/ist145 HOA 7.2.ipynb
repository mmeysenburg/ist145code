# %% [markdown]
# #HOA 7.2
#
# In this set of activities, we will practice with regular expressions and pattern matching.
#
# ---
#
# Execute the code in the following cell to access the file required for this HOA.
#
# ---

# %%
# !curl 'https://raw.githubusercontent.com/mmeysenburg/ist145code/main/module07/wordlist.txt' > wordlist.txt

# %% [markdown]
# ##1 Regular Expressions
#
# In the cells below you will practice creating a variety of regular expressions, and then you will create lists of dictionary words that match each of the patterns you create.

# %% [markdown]
# ___
#
# ###1.1 Define the `checkWord()` Function
#
# First, execute the cell below to define the `checkWord()` function, which is taken directly from Listing 8.11 of your text. This function takes a regular expression pattern as a parameter, and returns a list of all the dictionary words that match that pattern.
#
# Also, if needed, be sure to upload the `wordlist.txt` file, which is the list of valid dictionary words.

# %%
import re

def checkWord(regex):
  """
  Return a list of dictionary words matching a regular expression.

  parameters
  ----------
  regex : str
    Regular expression to match.

  returns
  -------
    A list of words matching the regular expression. 
  """
    
  resList = []
  with open('wordlist.txt', 'r') as wordFile:
    for line in wordFile:
      if re.match(regex, line[:-1]):
        resList.append(line[:-1])

  return resList

# %% [markdown]
# ###1.2 Make Your Expressions
#
# Now let's create some patterns! In each of the code cells below, follow the instructions in the comments to create the specified regular expressions.
#
# Refer to Table 8.13 in your text for a summary of regular expression syntax. Also, you may wish to make use of the `string.ascii_lowercase` constant to save you some typing.

# %%
import string

# TODO: Write a regular expression pattern to match all words ending in 's'.
pattern = 

# Get a list of all dictionary words ending with s
list01 = checkWord(pattern)
print(list01)

# %%
# execute this code to check your expression
sum = 0
for word in list01:
  if word.endswith('s'):
    sum += 1

if sum == 3794:
  print('AWESOME!')
else:
  print('Something went wrong.')

# %%
# TODO: Write a regular expression pattern to match all words ending in 'ing'.
pattern = 

# Get a list of all dictionary words ending with ing
list02 = checkWord(pattern)
print(list02)

# %%
# execute this code to check your expression
sum = 0
for word in list02:
  if word.endswith('ing'):
    sum += 1

if sum == 1240:
  print('AWESOME!')
else:
  print('Something went wrong.')

# %%
# TODO: Write a regular expression pattern to match all words with 'ss' anywhere in the word
pattern = 

# Get a list of all dictionary words with ss anywhere in the word
list03 = checkWord(pattern)
print(list03)

# %%
# execute this code to check your expression
sum = 0
for word in list03:
  if 'ss' in word:
    sum += 1

if sum == 2764:
  print('AWESOME!')
else:
  print('Something went wrong.')

# %%
# TODO: Write a regular expression pattern to match all words beginning and ending with the letter 'a'
pattern = 

# Get a list of all dictionary words beginning and ending with a
list04 = checkWord(pattern)
print(list04)

# %%
# execute this code to check your expression
sum = 0
for word in list04:
  if word.startswith('a') and word.endswith('a'):
    sum += 1

if sum == 58:
  print('AWESOME!')
else:
  print('Something went wrong.')

# %%
# TODO: Write a regular expression pattern to match all the words that start with 'st'
pattern = 

# Get a list of all dictionary words starting with st
list05 = checkWord(pattern)
print(list05)

# %%
# execute this code to check your expression
sum = 0
for word in list05:
  if word.startswith('st'):
    sum += 1

if sum == 701:
  print('AWESOME!')
else:
  print('Something went wrong.')

# %%
# TODO: Write a regular expression to match all the four-letter words where the middle two letters are vowels
# (assume y is a vowel for this expression)
pattern = 

# Get a list of all dictionary words matching the pattern
list06 = checkWord(pattern)
print(list06)

# %%
# execute this code to check your expression
sum = 0
for word in list06:
  if len(word) == 4 and word[1] in 'aeiouy' and word[2] in 'aeiouy':
    sum += 1

if sum == 335:
  print('AWESOME!')
else:
  print('Something went wrong.')
