# %% [markdown]
# #HOA 3.1
#
# To practice more with Python string objects, follow the instructions below.
#
# ---

# %% [markdown]
# ##1 Slices and Methods
#
# The exercises below will help you practice with slicing and string methods. Refer to sections 3.1 through 3.2.6 of your text if you need to review or look up specific method syntax.

# %% [markdown]
# ###1.1 Experiment with slicing
#
# * Create a string variable that is initialized to your entire name -- first, middle, and last (e.g., Mark Matthew Meysenburg; feel free to make up a name if you wish)
#
# * Using the slice operator, print out only your first name
#
# * Using the slice operator, print out only your last name
#
# * Using the slice and concatenation operators, print out your name in the form `Lastname, Firstname`
#
# * Use the `len()` function to print out the length of your entire name (including spaces, etc.)

# %%
# write your code here
name = 'Mark Matthew Meysenburg'
first = name[:4]
last = name[13:]
print(first)
print(last)
print(last + ', ' + first)
print(len(name), 'characters in', name)
# Out:
# Mark
# Meysenburg
# Meysenburg, Mark
# 23 characters in Mark Matthew Meysenburg

# %% [markdown]
# ###1.2 Go to Mississippi
#
# Assume you have two variables: `s = 's'` and `p = 'p'`.
#
# * Using the concatenation and repetition operators, write an expression that produces the string `mississippi`; assign some variable name to the result of your expression
#
# * Use string methods to do the following:
#
#     * Find the number of occurrences of the character `'s'` in the string `'mississippi'`
#
#     * In the string `'mississippi'`, replace all occurrences of the substring `'iss'` with `'ox'`
#
#     * Find the index of the first occurrence of `'p'` in `'mississippi'`
#
# ---

# %%
# variable declarations
s = 's'
p = 'p'

# write your code here
ms = 'mi' + s * 2 + 'i' + s * 2 + 'i' + p * 2 + 'i'
print(ms)
print('there are', ms.count('s'), "s's in", ms)
print(ms.replace('iss', 'ox'))
print('the first p in', ms, 'is at index', ms.find('p'))
# Out:
# mississippi
# there are 4 s's in mississippi
# moxoxippi
# the first p in mississippi is at index 8

# %% [markdown]
# ##2 NO SPACES!
#
# Now, let us solve a problem that might come up in cryptography: removing all of the spaces from some plaintext.

# %% [markdown]
# ###2.1 Write `stringSpaces()`
#
# Write a Python function `stripSpaces()` that takes a string representing a phrase as a parameter and returns the phrase with the order of the letters intact, but the spaces between each word removed. The first line of your function should be:
#
# `def stripSpaces(myString):`
#
# ---

# %%
# finish this function
def stripSpaces(myString):
  """
  Remove all of the spaces from a string.

  parameters
  ----------
  myString : string
    String to remove spaces from

  return
  ------
    A new string, equivalent to myString, but without spaces.
  """
  # This could also be done with a for loop
  return myString.replace(' ', '')

# %% [markdown]
# ###2.3 Test your `stripSpaces()` function
#
# Execute the following code cell. If you named your function as instructed, and it behaves as specified, you will see "Awesome!" as a result. If you get other output, fix your `stripSpaces()` function and try again.
#
# ---

# %%
testData = [('', ''), (' ', ''), ('this has no spaces', 'thishasnospaces'), 
            (' this either ', 'thiseither'), 
            (' 1 2 3 4 5 6 7 8 9 ', '123456789')]

numPassed = 0
for i, (w, wo) in enumerate(testData):
  print('test case {0:d}: "{1:s}" \t<-> \t"{2:2}"'.format(i, w, wo), end = '')
  realWo = stripSpaces(w)
  if wo == realWo:
    print('\tpassed')
    numPassed = numPassed + 1
  else:
    print('\tfailed')

if numPassed == len(testData):
  print('Awesome!')
# Out:
# test case 0: "" 	<-> 	"  "	passed
# test case 1: " " 	<-> 	"  "	passed
# test case 2: "this has no spaces" 	<-> 	"thishasnospaces"	passed
# test case 3: " this either " 	<-> 	"thiseither"	passed
# test case 4: " 1 2 3 4 5 6 7 8 9 " 	<-> 	"123456789"	passed
# Awesome!
